# %%
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport

# %%
df = pd.read_csv('Friday, Jul 13 2018.csv')
print(list(df))
df[df['SPEED'].between(0,50)]['SPEED'].plot(kind='hist',bins=20)
# Out:
# ['SITE_NUMBER', 'SITE_ID', 'SERIAL_NUMBER', 'DATE', 'TIME', 'TimeString', 'LANE', 'LANE_DETAILS', 'DIRECTION', 'DIRECTION_NUMBER', 'SPEED', 'SPEED_MPH', 'CLASS_INDEX', 'CLASS', 'LENGTH', 'AXLES', 'WHEELBASE', 'VALIDITY', 'STRADDLE', 'OVERLOADED', 'GROSS', 'HEADWAY', 'GAP', 'TIME_GAP', 'LEGAL_STATUS', 'CHASSIS_CODE', 'TEMP', 'AX_WT1', 'AX_WT2', 'AX_WT3', 'AX_WT4', 'AX_WT5', 'AX_WT6', 'AX_WT7', 'AX_WT8', 'AX_WT9', 'AX_WT10', 'AX_WT11', 'AX_WT12', 'AX_WT13', 'AX_WT14', 'AX_WT15', 'AX_WT16', 'AX_WT17', 'AX_WT18', 'AX_WT19', 'AX_WT20', 'AX_WT21', 'AX_WT22', 'AX_WT23', 'AX_WT24', 'AX_WT25', 'AXLE_TYPE_1', 'AXLE_TYPE_2', 'AXLE_TYPE_3', 'AXLE_TYPE_4', 'AXLE_TYPE_5', 'AXLE_TYPE_6', 'AXLE_TYPE_7', 'AXLE_TYPE_8', 'AXLE_TYPE_9', 'AXLE_TYPE_10', 'AXLE_TYPE_11', 'AXLE_TYPE_12', 'AXLE_TYPE_13', 'AXLE_TYPE_14', 'AXLE_TYPE_15', 'AXLE_TYPE_16', 'AXLE_TYPE_17', 'AXLE_TYPE_18', 'AXLE_TYPE_19', 'AXLE_TYPE_20', 'AXLE_TYPE_21', 'AXLE_TYPE_22', 'AXLE_TYPE_23', 'AXLE_TYPE_24', 'AXLE_TYPE_25', 'AX_SP1', 'AX_S
# ...

# %%
df2 = pd.read_csv('london_merged.csv')

# %%
profile = ProfileReport(df2,title="Test")

# %%
profile.to_file("Data report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# d:\U_targyak\MSC\VIZUÁLISADATELEMZÉS\.venv\lib\site-packages\multimethod\__init__.py:315: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   return func(*args, **kwargs)
# d:\U_targyak\MSC\VIZUÁLISADATELEMZÉS\.venv\lib\site-packages\multimethod\__init__.py:315: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   return func(*args, **kwargs)
# d:\U_targyak\MSC\VIZUÁLISADATELEMZÉS\.venv\lib\site-packages\multimethod\__init__.py:315: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# ...

# %%
profile.to_notebook_iframe()
# Out:
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.4.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-10-23 21:44:28.648070&quot;&gt;&lt;title&gt;Test&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df2.describe().transpose().to_csv('tmp.txt',sep='\t',mode='w')
